# %% [markdown]
# # Association Analysis Using FP-Growth

# %% [markdown]
# Recommendation System

# %%
#pip install mlxtend

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

# %%
#Import the data
transactions=[]
with open ('E:/Dataset/practise/Groceries.csv') as f:
    for line in f:
        transaction=[item for item in line.strip().split(',') if item != 'NaN'] 
        #All cell value splited by , and checking if the value is not NaN
        transactions.append(transaction)

# %%
len(transactions)
# Out:
# 9835

# %%
transactions[:3] #upto 3 transactions
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk']]

# %%
# create the object of TransactionEncoder
te = TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)

# %%
te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ...,  True, False, False],
#        ...,
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
te.columns_
# Out:
# ['Instant food products',
#  'UHT-milk',
#  'abrasive cleaner',
#  'artif. sweetener',
#  'baby cosmetics',
#  'baby food',
#  'bags',
#  'baking powder',
#  'bathroom cleaner',
#  'beef',
#  'berries',
#  'beverages',
#  'bottled beer',
#  'bottled water',
#  'brandy',
#  'brown bread',
#  'butter',
#  'butter milk',
#  'cake bar',
#  'candles',
#  'candy',
#  'canned beer',
#  'canned fish',
#  'canned fruit',
#  'canned vegetables',
#  'cat food',
#  'cereals',
#  'chewing gum',
#  'chicken',
#  'chocolate',
#  'chocolate marshmallow',
#  'citrus fruit',
#  'cleaner',
#  'cling film/bags',
#  'cocoa drinks',
#  'coffee',
#  'condensed milk',
#  'cooking chocolate',
#  'cookware',
#  'cream',
#  'cream cheese ',
#  'curd',
#  'curd cheese',
#  'decalcifier',
#  'dental care',
#  'dessert',
#  'detergent',
#  'dish cleaner',
#  'dishes',
#  'dog food',
#  'domestic eggs',
#  'female sanitary products',
#  'finished products',
#  'fish',
#  'flour',
#  'flower (seeds)',
#  'flower soil/fertilizer',
#  'frankfurter',
#  'frozen chicken',
#  'frozen dessert',
#  'frozen fish',
#  'frozen fruits',
#  'frozen meals',
#  'frozen potato products',
#  'frozen vegetables',
#  'fruit/vegetable juice',
#  'grapes',
#  'hair spray',
#  'ham',
#  'hamburger meat',
#  'hard cheese',
#  'herbs',
#  'honey',
#  'house keeping products',
#  'hygiene articles',
#  'ice cream',
#  'instant coffee',
#  'jam',
#  'ketchup',
#  'kitchen towels',
#  'kitchen utensil',
#  'light bulbs',
#  'liqueur',
#  'liquor',
#  'liquor (appetizer)',
#  'liver loaf',
#  'long life bakery product',
#  'make up remover',
#  'male cosmetics',
#  'margarine',
#  'mayonnaise',
#  'meat',
#  'meat spreads',
#  'misc. beverages',
#  'mustard',
#  'napkins',
#  'newspapers',
#  'nut snack',
#  'nuts/prunes',
#  'oil',
#  'onions',
#  'organic products',
#  'organic sausage',
#  'other vegetables',
#  'packaged fruit/vegetables',
#  'pasta',
#  'pastry',
#  'pet care',
#  'photo/film',
#  'pickled vegetables',
#  'pip fruit',
#  'popcorn',
#  'pork',
#  'pot plants',
#  'potato products',
#  'preservation products',
#  'processed cheese',
#  'prosecco',
#  'pudding powder',
#  'ready soups',
#  'red/blush wine',
#  'rice',
#  'roll products ',
#  'rolls/buns',
#  'root vegetables',
#  'rubbing alcohol',
#  'rum',
#  'salad dressing',
#  'salt',
#  'salty snack',
#  'sauces',
#  'sausage',
#  'seasonal products',
#  'semi-finished bread',
#  'shopping bags',
#  'skin care',
#  'sliced cheese',
#  'snack products',
#  'soap',
#  'soda',
#  'soft cheese',
#  'softener',
#  'sound storage medium',
#  'soups',
#  'sparkling wine',
#  'specialty bar',
#  'specialty cheese',
#  'specialty chocolate',
#  'specialty fat',
#  'specialty vegetables',
#  'spices',
#  'spread cheese',
#  'sugar',
#  'sweet spreads',
#  'syrup',
#  'tea',
#  'tidbits',
#  'toilet cleaner',
#  'tropical fruit',
#  'turkey',
#  'vinegar',
#  'waffles',
#  'whipped/sour cream',
#  'whisky',
#  'white bread',
#  'white wine',
#  'whole milk',
#  'yogurt',
#  'zwieback']

# %%
#will transform into a dataframe
df = pd.DataFrame(te_array,columns=te.columns_)
df.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# 1           False      False  False          False             False  False
# 2           False      False  False          False             False  False
# 3           False      False  False          False             False  False
# 4           False      False  False          False             False  False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False        True   False     False
# 3       False       False    True     False
# 4       False        True   False     False
#
# [5 rows x 169 columns]

# %%
#Build the rules using FP Growth
rules_df = fpgrowth(df, min_support=0.01, use_colnames=True, max_len=2) #maxlen is maximum combination

# %%
rules_df
# Out:
#       support                         itemsets
# 0    0.082766                   (citrus fruit)
# 1    0.058566                      (margarine)
# 2    0.017692            (semi-finished bread)
# 3    0.139502                         (yogurt)
# 4    0.104931                 (tropical fruit)
# ..        ...                              ...
# 296  0.010168  (frozen vegetables, rolls/buns)
# 297  0.012405      (yogurt, frozen vegetables)
# 298  0.014235       (other vegetables, onions)
# 299  0.012100             (whole milk, onions)
# 300  0.010778      (sliced cheese, whole milk)
#
# [301 rows x 2 columns]

# %%
rules_df = rules_df[rules_df.itemsets.map(len)==2] #extracting the combining products only

# %%
list(rules_df['itemsets'])[0]  #making a frozen set
# Out:
# frozenset({'citrus fruit', 'whole milk'})

# %%
tuple(list(rules_df['itemsets'])[0])[1]  #to drill down into frozen set
# Out:
# 'citrus fruit'

# %%
#From
rules_df['From']=rules_df['itemsets'].map(lambda x:list(x)[0])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\4065199812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_df['From']=rules_df['itemsets'].map(lambda x:list(x)[0])

# %%
#To
rules_df['To']=rules_df['itemsets'].map(lambda x:list(x)[1])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\4287823226.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_df['To']=rules_df['itemsets'].map(lambda x:list(x)[1])

# %%
rules_df.head()
# Out:
#      support                          itemsets              From  \
# 88  0.030503        (whole milk, citrus fruit)        whole milk
# 89  0.021657            (yogurt, citrus fruit)            yogurt
# 90  0.019929    (tropical fruit, citrus fruit)    tropical fruit
# 91  0.013523     (citrus fruit, bottled water)      citrus fruit
# 92  0.028876  (other vegetables, citrus fruit)  other vegetables
#
#                To
# 88   citrus fruit
# 89   citrus fruit
# 90   citrus fruit
# 91  bottled water
# 92   citrus fruit

# %%
#N = Support * Total number of transactions
rules_df['N']= (rules_df['support']*len(transactions)).astype(int)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\3675251811.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_df['N']= (rules_df['support']*len(transactions)).astype(int)

# %%
rules_df.head()
# Out:
#      support                          itemsets              From  \
# 88  0.030503        (whole milk, citrus fruit)        whole milk
# 89  0.021657            (yogurt, citrus fruit)            yogurt
# 90  0.019929    (tropical fruit, citrus fruit)    tropical fruit
# 91  0.013523     (citrus fruit, bottled water)      citrus fruit
# 92  0.028876  (other vegetables, citrus fruit)  other vegetables
#
#                To    N
# 88   citrus fruit  300
# 89   citrus fruit  213
# 90   citrus fruit  196
# 91  bottled water  133
# 92   citrus fruit  284

# %%
#Sorting the data based on N values 
rules_df.sort_values('N',ascending=False, inplace=True)
rules_df.head()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\4138473145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_df.sort_values('N',ascending=False, inplace=True)
#       support                             itemsets              From  \
# 146  0.074835       (other vegetables, whole milk)  other vegetables
# 157  0.056634             (whole milk, rolls/buns)        whole milk
# 107  0.056024                 (yogurt, whole milk)            yogurt
# 240  0.048907        (whole milk, root vegetables)        whole milk
# 238  0.047382  (other vegetables, root vegetables)  other vegetables
#
#                   To    N
# 146       whole milk  736
# 157       rolls/buns  557
# 107       whole milk  551
# 240  root vegetables  481
# 238  root vegetables  466

# %%
#lets take top 50 rules
rules_50=rules_df.head(50)
rules_50
# Out:
#       support                                itemsets              From  \
# 146  0.074835          (other vegetables, whole milk)  other vegetables
# 157  0.056634                (whole milk, rolls/buns)        whole milk
# 107  0.056024                    (yogurt, whole milk)            yogurt
# 240  0.048907           (whole milk, root vegetables)        whole milk
# 238  0.047382     (other vegetables, root vegetables)  other vegetables
# 110  0.043416              (yogurt, other vegetables)            yogurt
# 156  0.042603          (other vegetables, rolls/buns)  other vegetables
# 118  0.042298            (whole milk, tropical fruit)        whole milk
# 191  0.040061                      (whole milk, soda)        whole milk
# 190  0.038332                      (soda, rolls/buns)              soda
# 116  0.035892      (other vegetables, tropical fruit)  other vegetables
# 109  0.034367                    (yogurt, rolls/buns)            yogurt
# 165  0.034367             (whole milk, bottled water)        whole milk
# 227  0.033249                    (pastry, whole milk)            pastry
# 192  0.032740                (other vegetables, soda)  other vegetables
# 291  0.032232        (whole milk, whipped/sour cream)        whole milk
# 256  0.030605                   (sausage, rolls/buns)           sausage
# 88   0.030503              (whole milk, citrus fruit)        whole milk
# 132  0.030097                 (pip fruit, whole milk)         pip fruit
# 313  0.029995             (domestic eggs, whole milk)     domestic eggs
# 259  0.029893                   (sausage, whole milk)           sausage
# 115  0.029283                (yogurt, tropical fruit)            yogurt
# 168  0.028978                   (bottled water, soda)     bottled water
# 92   0.028876        (other vegetables, citrus fruit)  other vegetables
# 292  0.028876  (other vegetables, whipped/sour cream)  other vegetables
# 149  0.027555                    (whole milk, butter)        whole milk
# 209  0.027351                (whole milk, newspapers)        whole milk
# 108  0.027351                          (yogurt, soda)            yogurt
# 262  0.026945             (sausage, other vegetables)           sausage
# 217  0.026640     (whole milk, fruit/vegetable juice)        whole milk
# 137  0.026131           (pip fruit, other vegetables)         pip fruit
# 177  0.026131                      (curd, whole milk)              curd
# 241  0.025826               (yogurt, root vegetables)            yogurt
# 275  0.025216               (whole milk, brown bread)        whole milk
# 164  0.024809       (other vegetables, bottled water)  other vegetables
# 266  0.024606                   (soda, shopping bags)              soda
# 119  0.024606            (tropical fruit, rolls/buns)    tropical fruit
# 268  0.024504             (whole milk, shopping bags)        whole milk
# 239  0.024301           (root vegetables, rolls/buns)   root vegetables
# 257  0.024301                         (sausage, soda)           sausage
# 167  0.024199             (bottled water, rolls/buns)     bottled water
# 101  0.024199                 (whole milk, margarine)        whole milk
# 270  0.023183       (other vegetables, shopping bags)  other vegetables
# 166  0.022979                 (yogurt, bottled water)            yogurt
# 233  0.022572              (pastry, other vegetables)            pastry
# 318  0.022267       (domestic eggs, other vegetables)     domestic eggs
# 302  0.022166                      (whole milk, pork)        whole milk
# 89   0.021657                  (yogurt, citrus fruit)            yogurt
# 303  0.021657                (other vegetables, pork)  other vegetables
# 186  0.021251                      (beef, whole milk)              beef
#
#                         To    N
# 146             whole milk  736
# 157             rolls/buns  557
# 107             whole milk  551
# 240        root vegetables  481
# 238        root vegetables  466
# 110       other vegetables  427
# 156             rolls/buns  419
# 118         tropical fruit  416
# 191                   soda  394
# 190             rolls/buns  377
# 116         tropical fruit  353
# 109             rolls/buns  337
# 165          bottled water  337
# 227             whole milk  327
# 192                   soda  322
# 291     whipped/sour cream  317
# 256             rolls/buns  301
# 88            citrus fruit  300
# 132             whole milk  296
# 313             whole milk  295
# 259             whole milk  294
# 115         tropical fruit  288
# 168                   soda  285
# 92            citrus fruit  284
# 292     whipped/sour cream  284
# 149                 butter  271
# 209             newspapers  269
# 108                   soda  269
# 262       other vegetables  265
# 217  fruit/vegetable juice  262
# 137       other vegetables  257
# 177             whole milk  257
# 241        root vegetables  254
# 275            brown bread  248
# 164          bottled water  244
# 266          shopping bags  242
# 119             rolls/buns  242
# 268          shopping bags  241
# 239             rolls/buns  239
# 257                   soda  239
# 167             rolls/buns  238
# 101              margarine  238
# 270          shopping bags  228
# 166          bottled water  226
# 233       other vegetables  222
# 318       other vegetables  219
# 302                   pork  218
# 89            citrus fruit  213
# 303                   pork  213
# 186             whole milk  209

# %%
#list of all items
items=set(rules_df['From']) | set(rules_50['To'])

# %%
items
# Out:
# {'beef',
#  'berries',
#  'bottled beer',
#  'bottled water',
#  'brown bread',
#  'butter',
#  'canned beer',
#  'chocolate',
#  'citrus fruit',
#  'coffee',
#  'curd',
#  'dessert',
#  'domestic eggs',
#  'frankfurter',
#  'frozen vegetables',
#  'fruit/vegetable juice',
#  'long life bakery product',
#  'margarine',
#  'napkins',
#  'newspapers',
#  'other vegetables',
#  'pastry',
#  'pip fruit',
#  'pork',
#  'rolls/buns',
#  'root vegetables',
#  'sausage',
#  'shopping bags',
#  'sliced cheese',
#  'soda',
#  'sugar',
#  'tropical fruit',
#  'whipped/sour cream',
#  'whole milk',
#  'yogurt'}

# %%
#for i,itm in enumerate(items):
  #  print(i,itm)

# %%
#creating mapping of items to numbers
imap = {item: i for i, item in enumerate(items)}
#Maps the items to number and ads the numeric 'FromN' and 'ToN'
rules_50['FromN']=rules_50['From'].map(imap)
rules_50['ToN']=rules_50['To'].map(imap)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\3793324989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_50['FromN']=rules_50['From'].map(imap)
# C:\Users\dell\AppData\Local\Temp\ipykernel_4388\3793324989.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_50['ToN']=rules_50['To'].map(imap)

# %%
rules_50
# Out:
#       support                                itemsets              From  \
# 146  0.074835          (other vegetables, whole milk)  other vegetables
# 157  0.056634                (whole milk, rolls/buns)        whole milk
# 107  0.056024                    (yogurt, whole milk)            yogurt
# 240  0.048907           (whole milk, root vegetables)        whole milk
# 238  0.047382     (other vegetables, root vegetables)  other vegetables
# 110  0.043416              (yogurt, other vegetables)            yogurt
# 156  0.042603          (other vegetables, rolls/buns)  other vegetables
# 118  0.042298            (whole milk, tropical fruit)        whole milk
# 191  0.040061                      (whole milk, soda)        whole milk
# 190  0.038332                      (soda, rolls/buns)              soda
# 116  0.035892      (other vegetables, tropical fruit)  other vegetables
# 109  0.034367                    (yogurt, rolls/buns)            yogurt
# 165  0.034367             (whole milk, bottled water)        whole milk
# 227  0.033249                    (pastry, whole milk)            pastry
# 192  0.032740                (other vegetables, soda)  other vegetables
# 291  0.032232        (whole milk, whipped/sour cream)        whole milk
# 256  0.030605                   (sausage, rolls/buns)           sausage
# 88   0.030503              (whole milk, citrus fruit)        whole milk
# 132  0.030097                 (pip fruit, whole milk)         pip fruit
# 313  0.029995             (domestic eggs, whole milk)     domestic eggs
# 259  0.029893                   (sausage, whole milk)           sausage
# 115  0.029283                (yogurt, tropical fruit)            yogurt
# 168  0.028978                   (bottled water, soda)     bottled water
# 92   0.028876        (other vegetables, citrus fruit)  other vegetables
# 292  0.028876  (other vegetables, whipped/sour cream)  other vegetables
# 149  0.027555                    (whole milk, butter)        whole milk
# 209  0.027351                (whole milk, newspapers)        whole milk
# 108  0.027351                          (yogurt, soda)            yogurt
# 262  0.026945             (sausage, other vegetables)           sausage
# 217  0.026640     (whole milk, fruit/vegetable juice)        whole milk
# 137  0.026131           (pip fruit, other vegetables)         pip fruit
# 177  0.026131                      (curd, whole milk)              curd
# 241  0.025826               (yogurt, root vegetables)            yogurt
# 275  0.025216               (whole milk, brown bread)        whole milk
# 164  0.024809       (other vegetables, bottled water)  other vegetables
# 266  0.024606                   (soda, shopping bags)              soda
# 119  0.024606            (tropical fruit, rolls/buns)    tropical fruit
# 268  0.024504             (whole milk, shopping bags)        whole milk
# 239  0.024301           (root vegetables, rolls/buns)   root vegetables
# 257  0.024301                         (sausage, soda)           sausage
# 167  0.024199             (bottled water, rolls/buns)     bottled water
# 101  0.024199                 (whole milk, margarine)        whole milk
# 270  0.023183       (other vegetables, shopping bags)  other vegetables
# 166  0.022979                 (yogurt, bottled water)            yogurt
# 233  0.022572              (pastry, other vegetables)            pastry
# 318  0.022267       (domestic eggs, other vegetables)     domestic eggs
# 302  0.022166                      (whole milk, pork)        whole milk
# 89   0.021657                  (yogurt, citrus fruit)            yogurt
# 303  0.021657                (other vegetables, pork)  other vegetables
# 186  0.021251                      (beef, whole milk)              beef
#
#                         To    N  FromN  ToN
# 146             whole milk  736      0   21
# 157             rolls/buns  557     21   12
# 107             whole milk  551     19   21
# 240        root vegetables  481     21    7
# 238        root vegetables  466      0    7
# 110       other vegetables  427     19    0
# 156             rolls/buns  419      0   12
# 118         tropical fruit  416     21   10
# 191                   soda  394     21   34
# 190             rolls/buns  377     34   12
# 116         tropical fruit  353      0   10
# 109             rolls/buns  337     19   12
# 165          bottled water  337     21   16
# 227             whole milk  327     27   21
# 192                   soda  322      0   34
# 291     whipped/sour cream  317     21   11
# 256             rolls/buns  301     31   12
# 88            citrus fruit  300     21    1
# 132             whole milk  296     23   21
# 313             whole milk  295     25   21
# 259             whole milk  294     31   21
# 115         tropical fruit  288     19   10
# 168                   soda  285     16   34
# 92            citrus fruit  284      0    1
# 292     whipped/sour cream  284      0   11
# 149                 butter  271     21    5
# 209             newspapers  269     21   15
# 108                   soda  269     19   34
# 262       other vegetables  265     31    0
# 217  fruit/vegetable juice  262     21   14
# 137       other vegetables  257     23    0
# 177             whole milk  257     18   21
# 241        root vegetables  254     19    7
# 275            brown bread  248     21    2
# 164          bottled water  244      0   16
# 266          shopping bags  242     34   17
# 119             rolls/buns  242     10   12
# 268          shopping bags  241     21   17
# 239             rolls/buns  239      7   12
# 257                   soda  239     31   34
# 167             rolls/buns  238     16   12
# 101              margarine  238     21   20
# 270          shopping bags  228      0   17
# 166          bottled water  226     19   16
# 233       other vegetables  222     27    0
# 318       other vegetables  219     25    0
# 302                   pork  218     21   33
# 89            citrus fruit  213     19    1
# 303                   pork  213      0   33
# 186             whole milk  209     13   21
